# %%
coffee_menu = {'espresso': 1.50, 'americano' : 2.00, 'caffe latte': 2.25, 
               'mocha': 2.25, 'cappucino': 2.50, 'macchiato': 2.50} 
tea_menu = {'white tea': 1.50, 'green tea': 2.00, 'oolong tea': 2.25, 
          'black tea': 2.25, 'earl grey': 2.50, 'matcha': 2.50} 
pastries_menu = {'croissant': 5.50, 'cinnamon roll': 4.50, 'banana bread': 4.25, 
                 'pumpkin bread': 3.75, 'sticky bun': 4.25,      'apple turnover': 3.75}







mc_menu = {'espresso': 1.50, 'americano' : 2.00, 'caffe latte': 2.25, 
               'mocha': 2.25, 'cappucino': 2.50, 'macchiato': 2.50, 
          'white tea': 1.50, 'green tea': 2.00, 'oolong tea': 2.25, 
          'black tea': 2.25, 'earl grey': 2.50, 'matcha': 2.50, 
          'croissant': 5.50, 'cinnamon roll': 4.50, 'banana bread': 4.25, 
                 'pumpkin bread': 3.75, 'sticky bun': 4.25,      'apple turnover': 3.75}

# %%
full_order = {}
cust_order1 = ''
cust_order2 = float()
cust_question1 = ''
cust_question2 = ''


print("Welcome to MC Cafe!\n")

cust_question1 = input("Would you like to see the menu? (y/n): ")

if cust_question1 == 'n' :
    print("\nThanks for visiting MC Cafe!")
elif cust_question1 != 'y' and 'n' :
    print("\nThanks for visiting MC Cafe") 
else :
    print("\nCoffee Menu:")
    for key, value in coffee_menu.items() :
        print(f"{key.capitalize()}: ${value:.2f}")
    print("\nTea Menu:")
    for key, value in tea_menu.items() :
        print(f"{key.capitalize()}: ${value:.2f}")
    print("\nPastries Menu:")
    for key, value in pastries_menu.items() :
        print(f"{key.capitalize()}: ${value:.2f}")

    


        
   
    while cust_question1 == 'y' : 
        cust_order1 = mc_menu.keys()
        cust_order1 = (input("\nWhat would you like to order from the menu?: ")) 
        cust_order2 = mc_menu.get(cust_order1) 
        if cust_order2 == None :
            print("\nPlease order something from the menu.")
            continue
   
        
    

        cust_quant = int(input("\nHow many do you want? Please enter a whole number: "))
        if cust_quant == 0:
            print("\nPlease enter the item again.")
            continue
        
        
        cust_order3 = cust_order2 * cust_quant
   

        full_order[cust_order1] = cust_order3
    
   

        cust_question2 = input("\nDo you want to order something else? (y/n): ")
        if cust_question2 == 'y' :
            cust_question1 = 'y'
        elif cust_question2 == 'n' :
            break
        elif cust_question2 != 'y' and 'n' :
            print("\nPlease type a valid answer.")
            
     
       
    print("\nCustomer's Order:")
    for key, value in full_order.items() :
        print(f"{key.capitalize()}: ${value:.2f}")

    
   

    subtotal = cust_order4 * cust_quant
    print(f"\nSubtotal: {subtotal:.2f}")
    
    tax_percent = subtotal * .06
    print(f"Tax: {tax_percent:.2f}")
    
    customer_total = subtotal + tax_percent
    print(f"Total: {customer_total:.2f}")

print(f"\nThanks for visiting MC Cafe!")
# Out:
# Welcome to MC Cafe!
#
# Would you like to see the menu? (y/n): y
#
# Coffee Menu:
# Espresso: $1.50
# Americano: $2.00
# Caffe latte: $2.25
# Mocha: $2.25
# Cappucino: $2.50
# Macchiato: $2.50
#
# Tea Menu:
# White tea: $1.50
# Green tea: $2.00
# Oolong tea: $2.25
# Black tea: $2.25
# Earl grey: $2.50
# Matcha: $2.50
#
# Pastries Menu:
# Croissant: $5.50
# Cinnamon roll: $4.50
# Banana bread: $4.25
# Pumpkin bread: $3.75
# Sticky bun: $4.25
# Apple turnover: $3.75
#
# What would you like to order from the menu?: espresso
#
# How many do you want? Please enter a whole number: 2
#
# Do you want to order something else? (y/n): y
#
# What would you like to order from the menu?: americano
#
# Please order something from the menu.
#
# What would you like to order from the menu?: 2
#
# Please order something from the menu.
